# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys

print("at directory:", os.getcwd())
print("changing to root directory")
os.chdir("..")
print("at directory:", os.getcwd())
# Out:
# at directory: /Users/wilka/git/research/human-dyna-web
# changing to root directory
# at directory: /Users/wilka/git/research

# %%
# !pip install -e libraries/housemaze -e libraries/nicewebrl -e libraries/jaxneurorl -r requirements.txt

# %%
import jax
import jax.numpy as jnp
import functools
from functools import partial
import numpy as np
from pprint import pprint
import glob
from glob import glob
import matplotlib.pyplot as plt
import polars as pl
from tqdm.notebook import tqdm


from housemaze.human_dyna import mazes
from housemaze import renderer
from housemaze import utils
from housemaze.human_dyna import multitask_env as maze
from housemaze.human_dyna import experiments as housemaze_experiments

from jaxneurorl import launcher

from simulations import housemaze_trainer
from analysis import data_loading
from analysis import download_data
from analysis import housemaze as housemaze_analysis
from analysis import plots
from nicewebrl import dataframe

from nicewebrl import dataframe

from experiment_utils import SuccessTrackingAutoResetWrapper
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 22
#      18 from housemaze.human_dyna import experiments as housemaze_experiments
#      20 from jaxneurorl import launcher
# ---> 22 from simulations import housemaze_trainer
#      23 from analysis import data_loading
#      24 from analysis import download_data
#
# File ~/git/research/human-dyna-web/simulations/housemaze_trainer.py:40
#      35 import numpy as np
#      37 os.environ['XLA_PYTHON_CLIENT_PREALLOCATE']='false'
# ---> 40 from jaxneurorl.agents import value_based_basics as vbb
#      41 from jaxneurorl.agents import value_based_pqn as vpq
#      42 from jaxneurorl import launcher
#
# ImportError: cannot import name 'value_based_basics' from 'jaxneurorl.agents' (unknown location)

# %%
# data_dir = '/n/holylfs06/LABS/kempner_fellow_wcarvalho/results/jaxrl_result/housemaze_trainer'
data_dir = "/Users/wilka/git/research/results/human_dyna"

# %%
dummy_env_params = housemaze_analysis.get_params(mazes.big_practice_maze)
dummy_rng = jax.random.PRNGKey(42)
task_runner = maze.TaskRunner(task_objects=housemaze_analysis.task_objects)
base_env = maze.HouseMaze(
  task_runner=task_runner,
  num_categories=200,
)
env = utils.AutoResetWrapper(base_env)
nenvs = 25
example_timestep = env.reset(dummy_rng, dummy_env_params)

# %% [markdown]
# # Setup databases
#
# For every algorithm, for every experiment, we will
# 1. load the algorithm
# 2. collect K=100 episodes for that algorithm on task objects, we can choose multiple or 1 task object.
#     we'll always use the 1st task object from the train and test sets
# 3. for each of these K episodes, we're going to create an entry inside a polars dataframe including (1) whether eval or not, (2) algorithm (3) experiment (4) room (5) task_idx
#
# We'll want to options
# 1. if we reload this script, if possible load (a) algorithm df and (b) algorithm episodes from trajectory and don't recompute
# 3. option to force recomputation and overwrite data on disk
#
#
# In the end, we'll have dfs for every algorithm and an episode dict which goes (alg:list). we'll use these to two subselect data for different algorithms. we'll write a small select function which takes in this merged df and this episode dict
#
#
#
#
# We'll want to re-do this for users\

# %%
# !ls ~/git/research/results/human_dyna/model_data/*/save_data/*/*/*/analysis

# %%
# !rm -r ~/git/research/results/human_dyna/model_data/*/save_data/*/*/*/analysis

# %%
model_df_list = []
model_episodes_list = []

# %% [markdown]
# ### Q-learning

# %%
exp = "exp2"
qlearning_dir = download_data.qlearning_dir
paths = f"{data_dir}/model_data/{qlearning_dir}/*"
paths = glob(paths)

for path in tqdm(paths):
  seed = path.split("/")[-1].split("=")[-1]
  algorithm = data_loading.load_algorithm(
    path=path,
    name="qlearning",
    make_fns=functools.partial(
      housemaze_trainer.get_qlearning_fns, num_categories=10000
    ),
    env=env,
    example_env_params=dummy_env_params,
    nenvs=nenvs,
  )
  df, episodes = housemaze_analysis.get_algorithm_data(
    algorithm=algorithm, exp=exp, overwrite=False, extra_info=dict(seed=seed)
  )
  model_df_list.append(df)
  model_episodes_list.extend(episodes)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy

# %%
def first(eps):
  return jax.tree_map(lambda x: x[0], eps)


housemaze_analysis.render_path(first(episodes[0]))
df.head()
# Out:
# /var/folders/xy/l2ynyz5d10x4c52rnkln7tp80000gr/T/ipykernel_56589/2620379054.py:1: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   def first(eps): return jax.tree_map(lambda x:x[0], eps)
# shape: (5, 7)
# ┌───────┬───────────┬──────┬──────┬──────┬──────────────────────┬──────┐
# │ eval  ┆ algo      ┆ exp  ┆ room ┆ task ┆ maze_name            ┆ seed │
# │ ---   ┆ ---       ┆ ---  ┆ ---  ┆ ---  ┆ ---                  ┆ ---  │
# │ bool  ┆ str       ┆ str  ┆ i64  ┆ i64  ┆ str                  ┆ i64  │
# ╞═══════╪═══════════╪══════╪══════╪══════╪══════════════════════╪══════╡
# │ false ┆ qlearning ┆ exp2 ┆ 0    ┆ 26   ┆ big_m3_maze1         ┆ 3    │
# │ true  ┆ qlearning ┆ exp2 ┆ 0    ┆ 40   ┆ big_m3_maze1         ┆ 3    │
# │ false ┆ qlearning ┆ exp2 ┆ 0    ┆ 26   ┆ big_m2_maze2_onpath  ┆ 3    │
# │ true  ┆ qlearning ┆ exp2 ┆ 0    ┆ 40   ┆ big_m2_maze2_onpath  ┆ 3    │
# │ false ┆ qlearning ┆ exp2 ┆ 0    ┆ 26   ┆ big_m2_maze2_offpath ┆ 3    │
# └───────┴───────────┴──────┴──────┴──────┴──────────────────────┴──────┘

# %% [markdown]
# # Universal Successor Feature Approximators

# %%
from housemaze.human_dyna import sf_task_runner

task_runner_sf = sf_task_runner.TaskRunner(
  task_objects=housemaze_analysis.task_objects, vis_coeff=0.1, radius=5
)
sf_env = maze.HouseMaze(
  task_runner=task_runner_sf,
  num_categories=200,
)
sf_env = utils.AutoResetWrapper(sf_env)


exp = "exp2"
paths = f"{data_dir}/model_data/{download_data.sf_dir}/*"
paths = glob(paths)

for path in tqdm(paths):
  seed = path.split("/")[-1].split("=")[-1]
  algorithm = data_loading.load_algorithm(
    path=path,
    name="usfa",
    make_fns=functools.partial(
      housemaze_trainer.get_sf_fns, env=sf_env, env_params=dummy_env_params
    ),
    env=sf_env,
    example_env_params=dummy_env_params,
    nenvs=nenvs,
    config=dict(EVAL_TASK_SUPPORT="train"),
  )
  df, episodes = housemaze_analysis.get_algorithm_data(
    algorithm=algorithm,
    exp=exp,
    overwrite=False,
    extra_info=dict(seed=seed),
    data_task_runner=task_runner_sf,
  )
  model_df_list.append(df)
  model_episodes_list.extend(episodes)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy

# %%
def first(eps):
  return jax.tree_map(lambda x: x[0], eps)


housemaze_analysis.render_path(first(episodes[0]))
df.head()
# Out:
# /var/folders/xy/l2ynyz5d10x4c52rnkln7tp80000gr/T/ipykernel_56589/2620379054.py:1: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   def first(eps): return jax.tree_map(lambda x:x[0], eps)
# shape: (5, 7)
# ┌───────┬──────┬──────┬──────┬──────┬──────────────┬──────┐
# │ eval  ┆ algo ┆ exp  ┆ room ┆ task ┆ maze_name    ┆ seed │
# │ ---   ┆ ---  ┆ ---  ┆ ---  ┆ ---  ┆ ---          ┆ ---  │
# │ bool  ┆ str  ┆ str  ┆ i64  ┆ i64  ┆ str          ┆ i64  │
# ╞═══════╪══════╪══════╪══════╪══════╪══════════════╪══════╡
# │ false ┆ usfa ┆ exp2 ┆ 0    ┆ 26   ┆ big_m1_maze3 ┆ 1    │
# │ true  ┆ usfa ┆ exp2 ┆ 0    ┆ 40   ┆ big_m1_maze3 ┆ 1    │
# │ false ┆ usfa ┆ exp2 ┆ 0    ┆ 26   ┆ big_m2_maze2 ┆ 1    │
# │ true  ┆ usfa ┆ exp2 ┆ 0    ┆ 40   ┆ big_m2_maze2 ┆ 1    │
# │ false ┆ usfa ┆ exp2 ┆ 0    ┆ 26   ┆ big_m3_maze1 ┆ 1    │
# └───────┴──────┴──────┴──────┴──────┴──────────────┴──────┘

# %% [markdown]
# ### Dyna-Q

# %%
exp = "exp2"
# dyna_dir = f'ql/save_data/ql-21/exp={exp}'
dyna_dir = download_data.dyna_dir
paths = f"{data_dir}/model_data/{dyna_dir}/*"
paths = glob(paths)

for path in tqdm(paths):
  seed = path.split("/")[-1].split("=")[-1]
  algorithm = data_loading.load_algorithm(
    path=path,
    name="dynaq_shared",
    make_fns=functools.partial(
      housemaze_trainer.get_dynaq_fns,
      env=env,
      env_params=dummy_env_params,
      task_objects=housemaze_analysis.task_objects,
    ),
    env=env,
    example_env_params=dummy_env_params,
    nenvs=nenvs,
  )
  df, episodes = housemaze_analysis.get_algorithm_data(
    algorithm=algorithm, exp=exp, overwrite=False, extra_info=dict(seed=seed)
  )
  model_df_list.append(df)
  model_episodes_list.extend(episodes)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy

# %%
housemaze_analysis.render_path(first(episodes[-1]))
df.head()
# Out:
# /var/folders/xy/l2ynyz5d10x4c52rnkln7tp80000gr/T/ipykernel_56589/2620379054.py:1: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   def first(eps): return jax.tree_map(lambda x:x[0], eps)
# shape: (5, 7)
# ┌───────┬──────────────┬──────┬──────┬──────┬──────────────────────┬──────┐
# │ eval  ┆ algo         ┆ exp  ┆ room ┆ task ┆ maze_name            ┆ seed │
# │ ---   ┆ ---          ┆ ---  ┆ ---  ┆ ---  ┆ ---                  ┆ ---  │
# │ bool  ┆ str          ┆ str  ┆ i64  ┆ i64  ┆ str                  ┆ i64  │
# ╞═══════╪══════════════╪══════╪══════╪══════╪══════════════════════╪══════╡
# │ false ┆ dynaq_shared ┆ exp2 ┆ 0    ┆ 26   ┆ big_m3_maze1         ┆ 2    │
# │ true  ┆ dynaq_shared ┆ exp2 ┆ 0    ┆ 40   ┆ big_m3_maze1         ┆ 2    │
# │ false ┆ dynaq_shared ┆ exp2 ┆ 0    ┆ 26   ┆ big_m2_maze2_onpath  ┆ 2    │
# │ true  ┆ dynaq_shared ┆ exp2 ┆ 0    ┆ 40   ┆ big_m2_maze2_onpath  ┆ 2    │
# │ false ┆ dynaq_shared ┆ exp2 ┆ 0    ┆ 26   ┆ big_m2_maze2_offpath ┆ 2    │
# └───────┴──────────────┴──────┴──────┴──────┴──────────────────────┴──────┘

# %% [markdown]
# ### BFS/DFS

# %%
for algorithm in ["bfs", "dfs"]:
  df, episodes = housemaze_analysis.get_search_data(
    algorithm=algorithm,
    env=env,
    exp="exp2",
    base_path=f"{data_dir}/search_algos",
    budget=None,
    overwrite=False,
    searches=10,
  )
  model_df_list.append(df)
  model_episodes_list.extend(episodes)
# Out:
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy

# %%
housemaze_analysis.render_path(first(episodes[0]))
df.head()
# Out:
# /var/folders/xy/l2ynyz5d10x4c52rnkln7tp80000gr/T/ipykernel_56589/2620379054.py:1: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   def first(eps): return jax.tree_map(lambda x:x[0], eps)
# shape: (5, 7)
# ┌───────┬──────┬──────┬──────┬──────┬────────┬──────────────┐
# │ eval  ┆ algo ┆ exp  ┆ room ┆ task ┆ budget ┆ maze_name    │
# │ ---   ┆ ---  ┆ ---  ┆ ---  ┆ ---  ┆ ---    ┆ ---          │
# │ bool  ┆ str  ┆ str  ┆ i64  ┆ i64  ┆ str    ┆ str          │
# ╞═══════╪══════╪══════╪══════╪══════╪════════╪══════════════╡
# │ false ┆ dfs  ┆ exp2 ┆ 0    ┆ 26   ┆ null   ┆ big_m1_maze3 │
# │ true  ┆ dfs  ┆ exp2 ┆ 0    ┆ 40   ┆ null   ┆ big_m1_maze3 │
# │ false ┆ dfs  ┆ exp2 ┆ 0    ┆ 26   ┆ null   ┆ big_m2_maze2 │
# │ true  ┆ dfs  ┆ exp2 ┆ 0    ┆ 40   ┆ null   ┆ big_m2_maze2 │
# │ false ┆ dfs  ┆ exp2 ┆ 0    ┆ 26   ┆ null   ┆ big_m3_maze1 │
# └───────┴──────┴──────┴──────┴──────┴────────┴──────────────┘

# %% [markdown]
# ## put all model things together now

# %%
model_df = (
  pl.concat(model_df_list, how="diagonal_relaxed")
  .with_row_count(name="row_number")
  .with_columns(pl.col("row_number").alias("index"))
  .drop("row_number")
)
model_df = dataframe.DataFrame(
  df=model_df,
  episodes=model_episodes_list,
)
model_df.head()
# Out:
# /var/folders/xy/l2ynyz5d10x4c52rnkln7tp80000gr/T/ipykernel_56589/1099679968.py:2: DeprecationWarning: `DataFrame.with_row_count` is deprecated. Use `with_row_index` instead. Note that the default column name has changed from 'row_nr' to 'index'.
#   pl.concat(model_df_list, how="diagonal_relaxed")
# shape: (5, 9)
# ┌───────┬───────┬───────────┬──────┬───┬──────┬──────────────────────┬──────┬────────┐
# │ index ┆ eval  ┆ algo      ┆ exp  ┆ … ┆ task ┆ maze_name            ┆ seed ┆ budget │
# │ ---   ┆ ---   ┆ ---       ┆ ---  ┆   ┆ ---  ┆ ---                  ┆ ---  ┆ ---    │
# │ u32   ┆ bool  ┆ str       ┆ str  ┆   ┆ i64  ┆ str                  ┆ i64  ┆ str    │
# ╞═══════╪═══════╪═══════════╪══════╪═══╪══════╪══════════════════════╪══════╪════════╡
# │ 0     ┆ false ┆ qlearning ┆ exp2 ┆ … ┆ 26   ┆ big_m3_maze1         ┆ 1    ┆ null   │
# │ 1     ┆ true  ┆ qlearning ┆ exp2 ┆ … ┆ 40   ┆ big_m3_maze1         ┆ 1    ┆ null   │
# │ 2     ┆ false ┆ qlearning ┆ exp2 ┆ … ┆ 26   ┆ big_m2_maze2_onpath  ┆ 1    ┆ null   │
# │ 3     ┆ true  ┆ qlearning ┆ exp2 ┆ … ┆ 40   ┆ big_m2_maze2_onpath  ┆ 1    ┆ null   │
# │ 4     ┆ false ┆ qlearning ┆ exp2 ┆ … ┆ 26   ┆ big_m2_maze2_offpath ┆ 1    ┆ null   │
# └───────┴───────┴───────────┴──────┴───┴──────┴──────────────────────┴──────┴────────┘

# %% [markdown]
# # Human data

# %%
from analysis import data_loading
from analysis.download_data import download_user_files

bucket_name = "human-dyna"
prefix = "data/"
# pattern = "data/data_user=*_name=r0-v2*debug=0.json"
human_data_pattern = "data/data_user=*exp3*v3*debug=0.json"
destination_folder = "/Users/wilka/git/research/results/human_dyna/user_data/exp3"

download_user_files(bucket_name, prefix, human_data_pattern, destination_folder)
# Out:
# Downloaded: data/data_user=1031568544_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1031568544_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=1065979420_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1065979420_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=1157239186_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1157239186_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=1469588022_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1469588022_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=1506956932_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1506956932_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=1634437477_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1634437477_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=1673876325_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1673876325_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=1710663941_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1710663941_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=1732933377_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1732933377_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=1751525270_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1751525270_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=1804570266_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1804570266_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=1821828384_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1821828384_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=1871444059_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1871444059_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=1877894318_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1877894318_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=1976110140_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=1976110140_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=205072513_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=205072513_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=2074672944_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=2074672944_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=2122419407_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=2122419407_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=2198105127_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=2198105127_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=2414882660_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=2414882660_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=2509592_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=2509592_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=2540392743_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=2540392743_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=2657645499_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=2657645499_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=2675362775_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=2675362775_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=2861450138_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=2861450138_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=2863423409_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=2863423409_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=3018448105_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3018448105_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=3226840500_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3226840500_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=3259209746_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3259209746_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=3307723079_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3307723079_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=3372735581_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3372735581_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=3395296517_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3395296517_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=3408333974_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3408333974_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=3519024770_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3519024770_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=3608732212_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3608732212_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=3632701201_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3632701201_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=3673636578_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3673636578_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=3779690101_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3779690101_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=3877190768_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3877190768_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=3951666734_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3951666734_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=3952494503_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3952494503_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=3969272206_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=3969272206_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=400513251_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=400513251_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=469870683_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=469870683_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=551112125_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=551112125_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=728348694_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=728348694_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=729396272_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=729396272_name=exp3-v3-r0-t30_exp=3_debug=0.json
# Downloaded: data/data_user=834657846_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=834657846_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=871286831_name=exp3-v3-r1-t0_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=871286831_name=exp3-v3-r1-t0_exp=3_debug=0.json
# Downloaded: data/data_user=888509941_name=exp3-v3-r0-t30_exp=3_debug=0.json to /Users/wilka/git/research/results/human_dyna/user_data/exp3/data_user=888509941_name=exp3-v3-r0-t30_exp=3_debug=0.json

# %%
data_dir = "/Users/wilka/git/research/results/human_dyna/"
files = f"{data_dir}/user_data/*exp3*/*exp3*v3*t30*.json"
user_base_path = f"{data_dir}/user_data"
files = glob(files)
files, len(files)
# Out:
# (['/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=1732933377_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=3632701201_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=888509941_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=1751525270_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=2509592_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=2657645499_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=3408333974_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=2074672944_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=1506956932_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=3372735581_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=1877894318_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=551112125_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=729396272_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=728348694_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=2863423409_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=1710663941_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=2861450138_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=1469588022_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=400513251_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=3877190768_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=2414882660_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=1871444059_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=469870683_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=3673636578_name=exp3-v3-r0-t30_exp=3_debug=0.json',
#   '/Users/wilka/git/research/results/human_dyna//user_data/exp3/data_user=2122419407_name=exp3-v3-r0-t30_exp=3_debug=0.json'],
#  25)

# %%
web_env = SuccessTrackingAutoResetWrapper(base_env)
example_web_timestep = web_env.reset(dummy_rng, dummy_env_params)

# %%
# # TESTING
# import json
# file = files[1]
# with open(file, 'r') as f:
#     try:
#         data = json.load(f)
#     except Exception as e:
#         print('-'*25)
#         print(os.path.basename(file))
#         print(e)
# data_loading.make_episode_data(data=data, example_timestep=example_web_timestep, file=file)

# %%
# %debug
user_df = data_loading.make_all_episode_data(
  files=files,
  example_timestep=example_web_timestep,
  overwrite=False,
  # debug=True
)
user_df.head()
# Out:
# /Users/wilka/miniforge3/envs/preplay/lib/python3.10/site-packages/joblib/externals/loky/backend/fork_exec.py:38: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid = os.fork()
# Processing episodes:   0%|          | 0/56 [00:00<?, ?it/s]
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# Filtered 48 data points
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# Filtered 66 data points
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# Filtered 62 data points
# Processing episodes:   0%|          | 0/58 [00:00<?, ?it/s]
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# Filtered 56 data points
# Processing episodes:   0%|          | 0/80 [00:00<?, ?it/s]
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# Filtered 48 data points
# Processing episodes:   0%|          | 0/56 [00:00<?, ?it/s]
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# Filtered 52 data points
# Processing episodes:   2%|▏         | 1/56 [00:02<01:53,  2.06s/it]
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# Filtered 47 data points
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# Filtered 40 data points
# Processing episodes:   0%|          | 0/121 [00:00<?, ?it/s]
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# Filtered 61 data points
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# Filtered 59 data points
# Processing episodes: 100%|██████████| 39/39 [05:39<00:00,  8.72s/it]]
# Processing episodes:   0%|          | 0/76 [00:00<?, ?it/s]
# Filtered 47 data points
# Processing episodes: 100%|██████████| 56/56 [07:09<00:00,  7.67s/it]
# Processing episodes: 100%|██████████| 58/58 [09:37<00:00,  9.95s/it]]
# Processing episodes: 100%|██████████| 100/100 [09:38<00:00,  5.78s/it]
# Processing episodes: 100%|██████████| 81/81 [10:38<00:00,  7.88s/it]]
# Processing episodes: 100%|██████████| 56/56 [10:48<00:00, 11.58s/it]]
# Processing episodes: 100%|██████████| 56/56 [10:54<00:00, 11.69s/it]]
# Processing episodes: 100%|██████████| 76/76 [05:22<00:00,  4.24s/it]]
# Processing episodes: 100%|██████████| 80/80 [14:11<00:00, 10.64s/it]t]
# Processing episodes: 100%|██████████| 121/121 [14:58<00:00,  7.42s/it]
# Processing episodes: 100%|██████████| 137/137 [18:03<00:00,  7.91s/it]
# shape: (5, 16)
# ┌───────┬──────────────┬───────────┬──────────────┬───┬────────┬─────────────┬──────────┬──────────┐
# │ index ┆ maze         ┆ condition ┆ name         ┆ … ┆ sex    ┆ exp         ┆ new_path ┆ old_path │
# │ ---   ┆ ---          ┆ ---       ┆ ---          ┆   ┆ ---    ┆ ---         ┆ ---      ┆ ---      │
# │ u32   ┆ str          ┆ i64       ┆ str          ┆   ┆ str    ┆ str         ┆ bool     ┆ bool     │
# ╞═══════╪══════════════╪═══════════╪══════════════╪═══╪════════╪═════════════╪══════════╪══════════╡
# │ 0     ┆ big_m4_maze_ ┆ 0         ┆ big_m4_maze_ ┆ … ┆ Female ┆ exp3-v3-r0- ┆ null     ┆ null     │
# │       ┆ short        ┆           ┆ short        ┆   ┆        ┆ t30         ┆          ┆          │
# │ 1     ┆ big_m4_maze_ ┆ 0         ┆ big_m4_maze_ ┆ … ┆ Female ┆ exp3-v3-r0- ┆ null     ┆ null     │
# │       ┆ short        ┆           ┆ short        ┆   ┆        ┆ t30         ┆          ┆          │
# │ 2     ┆ big_m4_maze_ ┆ 0         ┆ big_m4_maze_ ┆ … ┆ Female ┆ exp3-v3-r0- ┆ null     ┆ null     │
# │       ┆ short        ┆           ┆ short        ┆   ┆        ┆ t30         ┆          ┆          │
# │ 3     ┆ big_m4_maze_ ┆ 0         ┆ big_m4_maze_ ┆ … ┆ Female ┆ exp3-v3-r0- ┆ null     ┆ null     │
# │       ┆ short        ┆           ┆ short        ┆   ┆        ┆ t30         ┆          ┆          │
# │ 4     ┆ big_m4_maze_ ┆ 0         ┆ big_m4_maze_ ┆ … ┆ Female ┆ exp3-v3-r0- ┆ null     ┆ null     │
# │       ┆ short        ┆           ┆ short        ┆   ┆        ┆ t30         ┆          ┆          │
# └───────┴──────────────┴───────────┴──────────────┴───┴────────┴─────────────┴──────────┴──────────┘

# %%
user_df["exp"].unique(), user_df["user_id"].unique()
# Out:
# (shape: (1,)
#  Series: 'exp' [str]
#  [
#  	"exp3-v3-r0-t30"
#  ],
#  shape: (20,)
#  Series: 'user_id' [i64]
#  [
#  	400513251
#  	469870683
#  	551112125
#  	729396272
#  	888509941
#  	…
#  	2863423409
#  	3372735581
#  	3632701201
#  	3673636578
#  	3877190768
#  ])

# %%
# sub = user_df.filter(eval=True)
# housemaze.create_episode_reaction_times_video(sub.episodes[0])

# %% [markdown]
# # Eval statistics

# %%
from IPython.display import Markdown, display
from analysis import housemaze
from analysis import plots
from analysis.plots import split_filter_fn, success_or_not_terminate, success

# %% [markdown]
# ## Paths manipulation (3)

# %%
# plots.m3_reaction_times(user_df, episode_selection='longest')

# %%
plots.m3_reaction_times(user_df, episode_selection="latest", ylim=[[0, 1.5], [0, 8]])
# Out:
# /Users/wilka/git/research/human-dyna-web/analysis/plots.py:1325: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_title(f'{rt_type.capitalize()} Reaction Time', fontsize=DEFAULT_TITLE_SIZE)
# /Users/wilka/git/research/human-dyna-web/analysis/plots.py:1325: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_title(f'{rt_type.capitalize()} Reaction Time', fontsize=DEFAULT_TITLE_SIZE)

# %%
plots.create_bar_plot_results_m3(user_df, model_df)

# %%
# %debug
plots.create_success_termination_results_m3(user_df, model_df)

# %%
plots.plot_episode_length_seconds(
  user_df,
  stages=["big_m3_maze1_eval"],
  settings=dict(eval=True),
  title_size=34,
  label_size=30,
)

# %%
display(
  Markdown("""
### epidoes where people take longer than 30 sconds
""")
)
# Out:
# ### epidoes where people take longer than 30 sconds

# %%
manipulation = 3

subset = user_df.subset(
  filter_fn=plots.split_filter_fn,
  output_filter_fn=lambda e: sum(e.reaction_times[:-1] / 1000.0) < 30,
  filter_settings=dict(eval=False),
  output_settings=dict(manipulation=manipulation, eval=True),
)

# %%
for i, e in enumerate(subset.episodes):
  print(i, e.reaction_times[:-1].sum() / 1000)
# Out:
# 0 39.611

# %%
housemaze.create_episode_reaction_times_video(subset.episodes[0])
# Out:
# <video width="800" height="400" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## Starting point manipulation (2)

# %%
plots.m2_reaction_time_difference(user_df, ["first", "avg"])

# %%
display(
  Markdown("""
### time(off-path) - time(on-path)
The RT when you're on oath should be smaller than off-path. Want this to be positive.
""")
)
# plots.m2_reaction_time_difference(user_df, ['first'], y_lim=[-2, 7])
plots.m2_reaction_time_difference(user_df, ["avg"], y_lim=[-1, 1])
# Out:
# ### time(off-path) - time(on-path)
# The RT when you're on oath should be smaller than off-path. Want this to be positive.

# %% [markdown]
# ## Planning manipulation (4) - short

# %%
# plots.plot_m4_example(user_df, 'short')

# %%
# OVERALL
# plots.m4_reaction_time_difference(user_df, setting='short', rt_types=['first'], ylim=[-1.5, 3])

# %%
# Overall
plots.m4_reaction_time_difference(
  user_df, setting="short", rt_types=["first"], ylim=[-1.5, 3]
)
# Out:
# removed: user 551112125 rate: 0.16129031777381897 = 5/31
# removed: user 1877894318 rate: 0.09677419066429138 = 3/31
# removed: user 2074672944 rate: 0.4444444477558136 = 8/18
# removed: user 2122419407 rate: 0.4444444477558136 = 8/18

# %%
plots.m4_action_reaction_time_difference(user_df, setting="short")
# Out:
# removed: user 551112125 rate: 0.16129031777381897 = 5/31
# removed: user 1877894318 rate: 0.09677419066429138 = 3/31
# removed: user 2074672944 rate: 0.4444444477558136 = 8/18
# removed: user 2122419407 rate: 0.4444444477558136 = 8/18
# /Users/wilka/git/research/human-dyna-web/analysis/plots.py:666: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#
# /Users/wilka/git/research/human-dyna-web/analysis/plots.py:666: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
plots.m4_initial_action_distribution(user_df, setting="short")
# Out:
# user 551112125 rate: 0.16129031777381897 = 5.0/31
# user 1877894318 rate: 0.09677419066429138 = 3.0/31
# user 2074672944 rate: 0.4444444477558136 = 8.0/18
# user 2122419407 rate: 0.4444444477558136 = 8.0/18

# %%
plots.m4_action_reaction_time_difference(
  user_df, setting="short", rt_types=["first"], ylim=[-1.5, 1.5]
)
# Out:
# removed: user 551112125 rate: 0.16129031777381897 = 5/31
# removed: user 1877894318 rate: 0.09677419066429138 = 3/31
# removed: user 2074672944 rate: 0.4444444477558136 = 8/18
# removed: user 2122419407 rate: 0.4444444477558136 = 8/18

# %%
# plots.m4_reaction_times(user_df, 'short', 'first', ylim=[0,4])
# Out:
# removed: user 551112125 rate: 0.16129031777381897 = 5/31
# removed: user 1877894318 rate: 0.09677419066429138 = 3/31
# removed: user 2074672944 rate: 0.4444444477558136 = 8/18
# removed: user 2122419407 rate: 0.4444444477558136 = 8/18
# /Users/wilka/git/research/human-dyna-web/analysis/plots.py:1148: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=45, ha='right')
# /Users/wilka/git/research/human-dyna-web/analysis/plots.py:1148: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=45, ha='right')

# %%
# plots.plot_path_lengths_m4(user_df, 'short')

# %% [markdown]
# ## Planning manipulation (4) - long

# %%
plots.m4_reaction_time_difference(user_df, setting="long", rt_types=["first", "avg"])
# Out:
# user 1871444059 rate: 0.2857142984867096 = 8.0/28
# Skipping 551112125
# Skipping 551112125

# %%
plots.m4_initial_action_distribution(user_df, setting="long")
# Out:
# removed: user 1871444059 rate: 0.2857142984867096 = 8/28

# %%
plots.m4_action_reaction_times_difference(
  user_df, "long", rt_types=["first"], ylim=[-4, 1]
)
# plots.m4_action_reaction_times_difference(user_df, 'short', 'speed', ylim=[-2, 1])
# Out:
# removed: user 1871444059 rate: 0.2857142984867096 = 8/28

# %%
# plots.m4_action_reaction_times(user_df, 'long', 'first')

# %%
# display(Markdown("""
# ### time(new target location) - time(old target path)
# The RT when location is new should be larger?
# """))

# plots.m4_reaction_time_difference(user_df, 'short')

# %%
# plots.m4_reaction_times(user_df, 'long')

# %%
# plots.m4_reaction_time_difference(user_df, 'long')

# %% [markdown]
# # Training statistics

# %%
# plots.plot_train_reaction_times_dual(user_df)

# %%
plots.plot_train_success_rate_histograms(user_df)

# %%
# plots.plot_episode_counts(user_df)

# %%
plots.plot_episode_length_seconds(user_df, title_size=34, label_size=30)
