# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

print("at directory:", os.getcwd())
print("changing to root directory")
os.chdir("..")
print("at directory:", os.getcwd())
# Out:
# at directory: /n/home13/wcarvalho/projects/preplay-human/analysis_notebooks
# changing to root directory
# at directory: /n/home13/wcarvalho/projects/preplay-human

# %%
sys.path.append("simulations")

# %%
# from analysis import craftax_model_data
import ipywidgets
from tqdm.notebook import tqdm
from IPython.display import display

from analysis import craftax_user_data
from analysis import craftax_analysis
import nicewebrl
import polars as pl


# %matplotlib inline
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# Loading Craftax textures from cache.
# Textures successfully loaded from cache.
# Loading textures from cache.
# Textures successfully loaded from cache.
# /n/home13/wcarvalho/projects/preplay-human/analysis/craftax_user_data.py:36: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
data_dir = "/Users/wilka/git/research/results/human_dyna/"

################
# Load model data
################
# %debug
model_df = housemaze_model_data.get_model_data(
  qlearning_path=f"{data_dir}/model_data/ql/save_data/ql-big-2/tota=40000000,exp=exp2/seed=*",
  sf_path=f"{data_dir}/model_data/usfa/save_data/usfa-big-10-search/sf_h=1024,num_=2,tota=40000000,exp=exp2/seed=*",
  dyna_path=f"{data_dir}/model_data/dynaq_shared/save_data/dynaq-big-4/alg=dynaq_shared,agen=256,tota=100000000,exp=exp2/seed=*",
  search_path=f"{data_dir}/search_algos",
  overwrite_episodes=False,
  overwrite_df=False,
)
# Out:
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# Error loading cached model data: No module named 'simulations.offtask_dyna'
#   0%|          | 0/5 [00:00<?, ?it/s]
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# qlearning: Loading from /Users/wilka/git/research/results/human_dyna//model_data/ql/save_data/ql-big-2/tota=40000000,exp=exp2/seed=1/analysis//qlearning_timesteps.pickle
# qlearning: Loaded 300 episodes
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# qlearning: Loading from /Users/wilka/git/research/results/human_dyna//model_data/ql/save_data/ql-big-2/tota=40000000,exp=exp2/seed=2/analysis//qlearning_timesteps.pickle
# qlearning: Loaded 300 episodes
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# qlearning: Loading from /Users/wilka/git/research/results/human_dyna//model_data/ql/save_data/ql-big-2/tota=40000000,exp=exp2/seed=5/analysis//qlearning_timesteps.pickle
# qlearning: Loaded 300 episodes
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# qlearning: Loading from /Users/wilka/git/research/results/human_dyna//model_data/ql/save_data/ql-big-2/tota=40000000,exp=exp2/seed=4/analysis//qlearning_timesteps.pickle
# qlearning: Loaded 300 episodes
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# qlearning: Loading from /Users/wilka/git/research/results/human_dyna//model_data/ql/save_data/ql-big-2/tota=40000000,exp=exp2/seed=3/analysis//qlearning_timesteps.pickle
# qlearning: Loaded 300 episodes
#   0%|          | 0/1 [00:00<?, ?it/s]
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# usfa: Loading from /Users/wilka/git/research/results/human_dyna//model_data/usfa/save_data/usfa-big-10-search/sf_h=1024,num_=2,tota=40000000,exp=exp2/seed=1/analysis//usfa_timesteps.pickle
# usfa: Loaded 12 episodes
#   0%|          | 0/2 [00:00<?, ?it/s]
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# dynaq_shared: Loading from /Users/wilka/git/research/results/human_dyna//model_data/dynaq_shared/save_data/dynaq-big-4/alg=dynaq_shared,agen=256,tota=100000000,exp=exp2/seed=1/analysis//dynaq_shared_timesteps.pickle
# dynaq_shared: Loaded 300 episodes
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# dynaq_shared: Loading from /Users/wilka/git/research/results/human_dyna//model_data/dynaq_shared/save_data/dynaq-big-4/alg=dynaq_shared,agen=256,tota=100000000,exp=exp2/seed=2/analysis//dynaq_shared_timesteps.pickle
# dynaq_shared: Loaded 300 episodes
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# bfs: Loading from /Users/wilka/git/research/results/human_dyna//search_algos/analysis//bfs_timesteps.pickle
# bfs: planning:   0%|          | 0/100 [00:00<?, ?it/s]
# bfs: Loaded 1200 episodes
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# dfs: Loading from /Users/wilka/git/research/results/human_dyna//search_algos/analysis//dfs_timesteps.pickle
# dfs: planning:   0%|          | 0/100 [00:00<?, ?it/s]
# dfs: Loaded 1200 episodes
# Cached model data to /Users/wilka/git/research/results/human_dyna//model_data/ql/save_data/ql-big-2/tota=40000000,exp=exp2/model_data_cache_episodes.pickle

# %%
# model_df = model_df.rename({'went_to_junction': 'reuse'})

# %% [markdown]
# # Human data

# %%
# ON SERVER
RESULTS_DIR ='/n/holylfs06/LABS/kempner_fellow_wcarvalho'
USER_RESULTS_DIR = os.path.join(RESULTS_DIR, 'results/human_dyna_craftax/user_data/exps')

# %%
# # ON COMPUTER
# RESULTS_DIR ='/Users/wilka/git/research/'
# USER_RESULTS_DIR = os.path.join(RESULTS_DIR, 'results/human_dyna_craftax/user_data/exps')

# %%
from glob import glob

files = f"{USER_RESULTS_DIR}/*v3*.json"
files = list(set(glob(files)))
len(files)
# Out:
# 43

# %%
import craftax_experiment_structure as experiment
import asyncio

# %debug
user_df = await craftax_user_data.get_human_data(
    files,
    overwrite_episode_data=False,
    overwrite_episode_info=False,
    debug=False,
)
# Out:
# Compiling environment reset and step functions.
# 	reset time: 23.30576467514038
# 	step time: 27.707179069519043
# Compiling multi-render function.
# 	time: 5.304262161254883
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=4026486179_worker=AL4L3QR3HVITQ_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=4026486179_worker=AL4L3QR3HVITQ_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 0/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=4026486179_worker=AL4L3QR3HVITQ_name=craftax_v3-paths-r1-m0_debug=0.json
# 1/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=93442868_worker=AKVQQVJKH11HQ_name=craftax_v3-paths-r1-m0_debug=0.json
# skipping /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=93442868_worker=AKVQQVJKH11HQ_name=craftax_v3-paths-r1-m0_debug=0.json because one of the episode_df or episode_data is None
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2679367757_worker=A3V9JFVZQ2XF4Y_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2679367757_worker=A3V9JFVZQ2XF4Y_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 2/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2679367757_worker=A3V9JFVZQ2XF4Y_name=craftax_v3-paths-r1-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3035036726_worker=A1D2W776ISG99K_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3035036726_worker=A1D2W776ISG99K_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 3/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=3035036726_worker=A1D2W776ISG99K_name=craftax_v3-paths-r1-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2829952107_worker=A11FRLH5KWRLBV_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2829952107_worker=A11FRLH5KWRLBV_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 4/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2829952107_worker=A11FRLH5KWRLBV_name=craftax_v3-paths-r1-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3817231829_worker=A2H6284K99459A_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3817231829_worker=A2H6284K99459A_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 5/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=3817231829_worker=A2H6284K99459A_name=craftax_v3-paths-r0-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2635592883_worker=A6MWJK1YEY5L2_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2635592883_worker=A6MWJK1YEY5L2_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 6/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2635592883_worker=A6MWJK1YEY5L2_name=craftax_v3-paths-r0-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3579708072_worker=A50K26F2IS94U_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3579708072_worker=A50K26F2IS94U_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 7/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=3579708072_worker=A50K26F2IS94U_name=craftax_v3-paths-r1-m0_debug=0.json
# Failed to unpack record in /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=1641903520_worker=A3BUPP17GN7I1H_name=craftax_v3-paths-r0-m0_debug=0.json: unpack(b) received extra data.
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=1382413084_worker=A34930YXVQ8SUT_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=1382413084_worker=A34930YXVQ8SUT_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 8/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=1382413084_worker=A34930YXVQ8SUT_name=craftax_v3-paths-r1-m0_debug=0.json
# 9/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=1641903520_worker=A3BUPP17GN7I1H_name=craftax_v3-paths-r0-m0_debug=0.json
# skipping /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=1641903520_worker=A3BUPP17GN7I1H_name=craftax_v3-paths-r0-m0_debug=0.json because one of the episode_df or episode_data is None
# Failed to unpack record in /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=1207509733_worker=A1F6MWP9A0XLJQ_name=craftax_v3-paths-r1-m0_debug=0.json: unpack(b) received extra data.
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=1575818269_worker=A25BFYCETHHKN3_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=1575818269_worker=A25BFYCETHHKN3_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 10/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=1575818269_worker=A25BFYCETHHKN3_name=craftax_v3-paths-r1-m0_debug=0.json
# 11/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=1207509733_worker=A1F6MWP9A0XLJQ_name=craftax_v3-paths-r1-m0_debug=0.json
# skipping /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=1207509733_worker=A1F6MWP9A0XLJQ_name=craftax_v3-paths-r1-m0_debug=0.json because one of the episode_df or episode_data is None
# Failed to unpack record in /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=311884650_worker=A3BUPP17GN7I1H_name=craftax_v3-paths-r1-m0_debug=0.json: unpack(b) received extra data.
# 12/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=311884650_worker=A3BUPP17GN7I1H_name=craftax_v3-paths-r1-m0_debug=0.json
# skipping /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=311884650_worker=A3BUPP17GN7I1H_name=craftax_v3-paths-r1-m0_debug=0.json because one of the episode_df or episode_data is None
# 13/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=1457857247_worker=A1A2O70XEO2YYQ_name=craftax_v3-paths-r1-m0_debug=0.json
# skipping /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=1457857247_worker=A1A2O70XEO2YYQ_name=craftax_v3-paths-r1-m0_debug=0.json because one of the episode_df or episode_data is None
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2349435691_worker=A3J0IAI8AJBGKX_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2349435691_worker=A3J0IAI8AJBGKX_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 14/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2349435691_worker=A3J0IAI8AJBGKX_name=craftax_v3-paths-r0-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2951292398_worker=ASUYD8BPYM85M_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2951292398_worker=ASUYD8BPYM85M_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 15/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2951292398_worker=ASUYD8BPYM85M_name=craftax_v3-paths-r0-m0_debug=0.json
# 16/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2998019967_worker=A3QNCW3LR2AVOV_name=craftax_v3-paths-r0-m0_debug=0.json
# skipping /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2998019967_worker=A3QNCW3LR2AVOV_name=craftax_v3-paths-r0-m0_debug=0.json because one of the episode_df or episode_data is None
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2965728029_worker=A1TARNH07A75CG_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2965728029_worker=A1TARNH07A75CG_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 17/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2965728029_worker=A1TARNH07A75CG_name=craftax_v3-paths-r1-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=122928105_worker=A3N770LD28YDL1_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=122928105_worker=A3N770LD28YDL1_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 18/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=122928105_worker=A3N770LD28YDL1_name=craftax_v3-paths-r0-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=818906834_worker=A3RCX3IQ8L6HHW_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=818906834_worker=A3RCX3IQ8L6HHW_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 19/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=818906834_worker=A3RCX3IQ8L6HHW_name=craftax_v3-paths-r0-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3638567733_worker=A1AZGP16G9TURZ_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3638567733_worker=A1AZGP16G9TURZ_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 20/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=3638567733_worker=A1AZGP16G9TURZ_name=craftax_v3-paths-r0-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2540827707_worker=A3GWRDHAURRNK6_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2540827707_worker=A3GWRDHAURRNK6_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 21/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2540827707_worker=A3GWRDHAURRNK6_name=craftax_v3-paths-r0-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=1203630643_worker=A2G7N0X0PNX0EE_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=1203630643_worker=A2G7N0X0PNX0EE_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 22/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=1203630643_worker=A2G7N0X0PNX0EE_name=craftax_v3-paths-r1-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2617232665_worker=A2SKY4RRWII0BF_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2617232665_worker=A2SKY4RRWII0BF_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 23/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2617232665_worker=A2SKY4RRWII0BF_name=craftax_v3-paths-r0-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=1566204710_worker=A3GWRDHAURRNK6_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=1566204710_worker=A3GWRDHAURRNK6_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 24/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=1566204710_worker=A3GWRDHAURRNK6_name=craftax_v3-paths-r1-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2009763096_worker=A2ZYZ05XQ6TLOT_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2009763096_worker=A2ZYZ05XQ6TLOT_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 25/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2009763096_worker=A2ZYZ05XQ6TLOT_name=craftax_v3-paths-r1-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3651975810_worker=ABBZGF22NICO7_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3651975810_worker=ABBZGF22NICO7_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 26/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=3651975810_worker=ABBZGF22NICO7_name=craftax_v3-paths-r0-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3469065797_worker=A2HEZ4001GAES4_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# A* Iterations: 0it [00:00, ?it/s]
# /n/home13/wcarvalho/.conda/envs/preplay/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /n/home13/wcarvalho/.conda/envs/preplay/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# error processing /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=3469065797_worker=A2HEZ4001GAES4_name=craftax_v3-paths-r0-m0_debug=0.json: zero-size array to reduction operation maximum which has no identity
# Failed to unpack record in /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=957564031_worker=AJQ71YIGY01HZ_name=craftax_v3-paths-r0-m0_debug=0.json: unpack(b) received extra data.
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2933138588_worker=AU849EHZNGV2Z_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2933138588_worker=AU849EHZNGV2Z_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 28/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2933138588_worker=AU849EHZNGV2Z_name=craftax_v3-paths-r1-m0_debug=0.json
# 29/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=957564031_worker=AJQ71YIGY01HZ_name=craftax_v3-paths-r0-m0_debug=0.json
# skipping /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=957564031_worker=AJQ71YIGY01HZ_name=craftax_v3-paths-r0-m0_debug=0.json because one of the episode_df or episode_data is None
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3150828290_worker=A1S8DYWNS59XWB_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3150828290_worker=A1S8DYWNS59XWB_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 30/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=3150828290_worker=A1S8DYWNS59XWB_name=craftax_v3-paths-r0-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2836227078_worker=A367DFRENYZ3IM_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2836227078_worker=A367DFRENYZ3IM_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 31/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2836227078_worker=A367DFRENYZ3IM_name=craftax_v3-paths-r0-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3385462005_worker=A2NR6DBUEXC3Y4_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3385462005_worker=A2NR6DBUEXC3Y4_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 32/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=3385462005_worker=A2NR6DBUEXC3Y4_name=craftax_v3-paths-r0-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2336537156_worker=A9S6EGIY10U0X_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2336537156_worker=A9S6EGIY10U0X_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 33/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2336537156_worker=A9S6EGIY10U0X_name=craftax_v3-paths-r1-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=10434196_worker=A2EH7IQCDH2Q5D_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=10434196_worker=A2EH7IQCDH2Q5D_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 34/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=10434196_worker=A2EH7IQCDH2Q5D_name=craftax_v3-paths-r0-m0_debug=0.json
# Failed to unpack record in /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2343945951_worker=A3KXCBNBQAU992_name=craftax_v3-paths-r1-m0_debug=0.json: unpack(b) received extra data.
# 35/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2343945951_worker=A3KXCBNBQAU992_name=craftax_v3-paths-r1-m0_debug=0.json
# skipping /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2343945951_worker=A3KXCBNBQAU992_name=craftax_v3-paths-r1-m0_debug=0.json because one of the episode_df or episode_data is None
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=4044144099_worker=A18E16UFE351U6_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=4044144099_worker=A18E16UFE351U6_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 36/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=4044144099_worker=A18E16UFE351U6_name=craftax_v3-paths-r1-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3602276455_worker=A13I8ASC3JQ04P_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=3602276455_worker=A13I8ASC3JQ04P_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 37/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=3602276455_worker=A13I8ASC3JQ04P_name=craftax_v3-paths-r1-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=4233642709_worker=A2FHM2F9QKP0O0_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=4233642709_worker=A2FHM2F9QKP0O0_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 38/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=4233642709_worker=A2FHM2F9QKP0O0_name=craftax_v3-paths-r0-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=213640548_worker=A2FHM2F9QKP0O0_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=213640548_worker=A2FHM2F9QKP0O0_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 39/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=213640548_worker=A2FHM2F9QKP0O0_name=craftax_v3-paths-r1-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2230958349_worker=A3BSK47WPPE876_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=2230958349_worker=A3BSK47WPPE876_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 40/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=2230958349_worker=A3BSK47WPPE876_name=craftax_v3-paths-r1-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=4145025209_worker=A3BSK47WPPE876_name=craftax_v3-paths-r0-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=4145025209_worker=A3BSK47WPPE876_name=craftax_v3-paths-r0-m0_debug=0_episode_info.csv
# 41/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=4145025209_worker=A3BSK47WPPE876_name=craftax_v3-paths-r0-m0_debug=0.json
# Loaded episode data from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=630288606_worker=A18G2CLYSTENK_name=craftax_v3-paths-r1-m0_debug=0_episode_data.bytes
# Loaded episode info from /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps//user=630288606_worker=A18G2CLYSTENK_name=craftax_v3-paths-r1-m0_debug=0_episode_info.csv
# 42/43 /n/holylfs06/LABS/kempner_fellow_wcarvalho/results/human_dyna_craftax/user_data/exps/user=630288606_worker=A18G2CLYSTENK_name=craftax_v3-paths-r1-m0_debug=0.json

# %%
user_df.unique('reuse')
# Out:
# <div><style>
# .dataframe > thead > tr,
# .dataframe > tbody > tr {
#   text-align: right;
#   white-space: pre-wrap;
# }
# </style>
# <small>shape: (3, 36)</small><table border="1" class="dataframe"><thead><tr><th>index</th><th>world_seed</th><th>condition</th><th>name</th><th>block</th><th>manipulation</th><th>global_episode_idx</th><th>episode_idx</th><th>eval</th><th>task</th><th>room</th><th>start_pos</th><th>user_id</th><th>age</th><th>sex</th><th>exp_name</th><th>tell_reuse</th><th>eval_map</th><th>timer</th><th>version</th><th>optimal_length</th><th>success</th><th>path_length</th><th>termination</th><th>log_first_rt</th><th>log_avg_rt</th><th>log_total_rt</th><th>log_avg_post_rt</th><th>log_max_rt</th><th>log_max_post_rt</th><th>log_max_init_post_rt</th><th>log_max_end_rt</th><th>log_max_final_rt</th><th>optimal_length_deviance</th><th>reuse</th><th>overlap</th></tr><tr><td>u32</td><td>i64</td><td>i64</td><td>str</td><td>str</td><td>str</td><td>i64</td><td>i64</td><td>bool</td><td>i64</td><td>i64</td><td>str</td><td>i64</td><td>i64</td><td>str</td><td>str</td><td>i64</td><td>i64</td><td>i64</td><td>i64</td><td>i64</td><td>f64</td><td>i64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>f64</td><td>i64</td><td>str</td><td>str</td></tr></thead><tbody><tr><td>0</td><td>95</td><td>1</td><td>&quot;paths_3_eval1&quot;</td><td>&quot;reusing longer of two paths wh…</td><td>&quot;paths&quot;</td><td>67</td><td>1</td><td>true</td><td>10</td><td>0</td><td>&quot;[ 7 16]&quot;</td><td>2679367757</td><td>43</td><td>&quot;Male&quot;</td><td>&quot;craftax_v3-paths-r1-m0&quot;</td><td>1</td><td>0</td><td>0</td><td>3</td><td>1</td><td>1.0</td><td>32</td><td>1.0</td><td>-2.063489</td><td>-1.211745</td><td>-38.775856</td><td>-1.18427</td><td>-0.579801</td><td>-0.579801</td><td>-0.911278</td><td>-0.579801</td><td>-0.579801</td><td>31</td><td>&quot;false&quot;</td><td>&quot;0.125&quot;</td></tr><tr><td>1</td><td>95</td><td>0</td><td>&quot;paths_3_training&quot;</td><td>&quot;reusing longer of two paths wh…</td><td>&quot;paths&quot;</td><td>0</td><td>1</td><td>false</td><td>22</td><td>1</td><td>&quot;[9 3]&quot;</td><td>4026486179</td><td>47</td><td>&quot;Female&quot;</td><td>&quot;craftax_v3-paths-r1-m0&quot;</td><td>1</td><td>0</td><td>0</td><td>3</td><td>1</td><td>0.0</td><td>87</td><td>1.0</td><td>1.4516162</td><td>-0.101128</td><td>-8.798122</td><td>-0.119183</td><td>1.4516162</td><td>0.590012</td><td>0.569289</td><td>0.5176085</td><td>0.590012</td><td>86</td><td>null</td><td>null</td></tr><tr><td>2</td><td>95</td><td>1</td><td>&quot;paths_3_eval1&quot;</td><td>&quot;reusing longer of two paths wh…</td><td>&quot;paths&quot;</td><td>19</td><td>1</td><td>true</td><td>10</td><td>0</td><td>&quot;[ 7 16]&quot;</td><td>4026486179</td><td>47</td><td>&quot;Female&quot;</td><td>&quot;craftax_v3-paths-r1-m0&quot;</td><td>1</td><td>0</td><td>0</td><td>3</td><td>1</td><td>1.0</td><td>44</td><td>1.0</td><td>2.507158</td><td>-0.098527</td><td>-4.335206</td><td>-0.159125</td><td>2.507158</td><td>0.7294839</td><td>0.273844</td><td>0.7294839</td><td>0.7294839</td><td>43</td><td>&quot;true&quot;</td><td>&quot;0.3125&quot;</td></tr></tbody></table></div>
