# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

print("at directory:", os.getcwd())
print("changing to root directory")
os.chdir("..")
print("at directory:", os.getcwd())
# Out:
# at directory: /Users/wilka/git/research/human-dyna-web/figures
# changing to root directory
# at directory: /Users/wilka/git/research/human-dyna-web

# %%
import matplotlib
# %matplotlib inline

# %%
import sys
sys.path.append("simulations")
import polars as pl
import jax

from analysis import housemaze_model_data
from analysis import housemaze_analysis
from figures import sf_analysis
# env, example_timestep = housemaze_model_data.load_env_and_example_timestep()
# Out:
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy

# %%
from housemaze.human_dyna import mazes
num_groups = 2
char2idx, groups, task_objects = mazes.get_group_set(num_groups)
task_objects = groups.reshape(-1)

from housemaze.human_dyna import utils
image_data = utils.load_image_dict()
image_keys = image_data["keys"]

object_to_name = {o:image_keys[o] for o in task_objects}
object_to_name
# Out:
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# {26: 'microwave', 40: 'stove', 47: 'fork', 43: 'knife'}

# %%
sf_df = sf_analysis.get_sf_df(overwrite_episodes=True, overwrite_df=True)
# Out:
# No file specified for image dict.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/image_data.pkl
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# No file specified for groups.
# Using: /Users/wilka/git/research/human-dyna-web/libraries/housemaze/housemaze/human_dyna/list_of_groups.npy
# > /Users/wilka/git/research/human-dyna-web/analysis/housemaze_model_data.py(406)get_algorithm_data()
#     405   ##############################
# --> 406   all_episodes = None
#     407
# ipdb>  all_train_objects
# ['microwave', 'fork']

# %%
sf_df.filter(EVAL_TASK_SUPPORT='train').head()
# Out:
# <div><style>
# .dataframe > thead > tr,
# .dataframe > tbody > tr {
#   text-align: right;
#   white-space: pre-wrap;
# }
# </style>
# ...

# %%
fig, ax = sf_analysis.make_sf_plot(sf_df, seed=1)
# Out:
# Saved figure to /Users/wilka/git/research/preplay_results/sf_analysis/plots/sf_plot_seed=1.pdf

# %%
fig, ax =  sf_analysis.make_sf_plot(sf_df, seed=2)
# Out:
# Saved figure to /Users/wilka/git/research/preplay_results/sf_analysis/plots/sf_plot_seed=2.pdf

# %%
fig, ax = sf_analysis.make_sf_plot(sf_df, seed=4)
# Out:
# Saved figure to /Users/wilka/git/research/preplay_results/sf_analysis/plots/sf_plot_seed=4.pdf
